# %% [markdown]
# # NEP → GAA Budget Anomaly Detection
#
# This notebook analyzes how proposed government budgets (NEP) change after approval (GAA).
# It identifies unusual budget adjustments to support transparency and public understanding.
#
# NEP = Proposed Budget
# GAA = Approved Budget

# %% [markdown]
# ## Background
#
# Government budgets go through a review process before final approval.
# While proposed (NEP) and approved (GAA) budgets are public, understanding how and where changes happen is difficult.
#
# This notebook focuses on:
# - Identifying large or unusual changes
# - Comparing regions fairly
# - Avoiding false alarms
# - Explaining results in simple language

# %% [markdown]
# ## Dataset Overview
#
# The dataset contains budget records with:
# - Budget type (NEP or GAA)
# - Fiscal year
# - Budget amount
# - Agency and region
# - Budget classification and object codes
#
# Only records from a selected agency are analyzed.

# %% [markdown]
# ## Key Definitions
#
# - NEP (National Expenditure Program): Proposed government budget
# - GAA (General Appropriations Act): Final approved budget
# - Budget Drift: Difference between NEP and GAA
# - Anomaly: A budget adjustment that is unusually large or inconsistent with peers or history
#
# Anomalies indicate items that may require review, not wrongdoing.

# %% [markdown]
# ## Data Preparation
#
# We separate NEP and GAA records and aggregate them to a comparable level
# to ensure fair comparison.

# %%
import pandas as pd

df = pd.DataFrame()

fiscl_years = [2020, 2021, 2022, 2023, 2024, 2025, 2026]

for year in fiscl_years:
    df_year = pd.read_parquet(f'cleaned_budget_{year}.parquet')
    df = pd.concat([df, df_year], ignore_index=True)

nep = df[df['budget_type'] == 'NEP']
gaa = df[df['budget_type'] == 'GAA']

# Aggregate to comparable level
group_cols = [
    'fiscal_year',
    'department_code',
    'department_name',
    'full_agency_code',
    'agency_name',
    'region_code',
    'region_description',
    'uacs_object_code',
    'uacs_sub_object_name'
]

nep_agg = nep.groupby(group_cols)['budget_amount'].sum().reset_index()
gaa_agg = gaa.groupby(group_cols)['budget_amount'].sum().reset_index()

merged = nep_agg.merge(
    gaa_agg,
    on=group_cols,
    suffixes=('_nep', '_gaa'),
    how='outer'
)

# %%
merged[(merged['budget_amount_nep'].isna())]
# Out:
#         fiscal_year department_code  \
# 46             2020              01
# 166            2020              01
# 285            2020              01
# 483            2020              03
# 1383           2020              04
# ...             ...             ...
# 328068         2025              38
# 328070         2025              38
# 328853         2025              38
# 329305         2025              39
# 329306         2025              39
#
#                                           department_name full_agency_code  \
# 46                 Congress of the Philippines (CONGRESS)            01001
# 166                Congress of the Philippines (CONGRESS)            01002
# 285                Congress of the Philippines (CONGRESS)            01004
# 483                    Office of the Vice-President (OVP)            03000
# 1383                  Department of Agrarian Reform (DAR)            04001
# ...                                                   ...              ...
# 328068                Department of Transportation (DOTr)            38003
# 328070                Department of Transportation (DOTr)            38003
# 328853                Department of Transportation (DOTr)            38006
# 329305  Department of Human Settlements and Urban Deve...            39001
# 329306  Department of Human Settlements and Urban Deve...            39001
#
#                                  agency_name region_code  \
# 46                                    Senate          13
# 166                Senate Electoral Tribunal          13
# 285                 House of Representatives          13
# 483       Office of the Vice-President (OVP)          13
# 1383                 Office of the Secretary          13
# ...                                      ...         ...
# 328068  Maritime Industry Authority (MARINA)          08
# 328070  Maritime Industry Authority (MARINA)          08
# 328853                Philippine Coast Guard          13
# 329305               Office of the Secretary          08
# 329306               Office of the Secretary          08
#
#                    region_description uacs_object_code  \
# 46      National Capital Region (NCR)       5021001000
# 166     National Capital Region (NCR)       5060699000
# 285     National Capital Region (NCR)       5060407001
# 483     National Capital Region (NCR)       5020702002
# 1383    National Capital Region (NCR)       5029999000
# ...                               ...              ...
# 328068  Region VIII - Eastern Visayas       5060405002
# 328070  Region VIII - Eastern Visayas       5060407001
# 328853  National Capital Region (NCR)       5060406099
# 329305  Region VIII - Eastern Visayas       5060405099
# 329306  Region VIII - Eastern Visayas       5060406001
#
#                                   uacs_sub_object_name  budget_amount_nep  \
# 46                               Confidential Expenses                NaN
# 166                            Other Intangible Assets                NaN
# 285                             Furniture and Fixtures                NaN
# 483     Research, Exploration and Development Expenses                NaN
# 1383          Other Maintenance and Operating Expenses                NaN
# ...                                                ...                ...
# 328068                                Office Equipment                NaN
# 328070                          Furniture and Fixtures                NaN
# 328853                  Other Transportation Equipment                NaN
# 329305                   Other Machinery and Equipment                NaN
# 329306                                  Motor Vehicles                NaN
#
#         budget_amount_gaa
# 46               100000.0
# 166                 150.0
# 285              200000.0
# 483               25000.0
# 1383                  0.0
# ...                   ...
# 328068             2501.0
# 328070            22000.0
# 328853           290000.0
# 329305             9370.0
# 329306            11041.0
#
# [5996 rows x 11 columns]

# %%
merged['unapproved_budget'] = merged['budget_amount_gaa'].isna()
merged['inserted_budget'] = merged['budget_amount_nep'].isna()
merged['budget_amount_gaa'] = merged['budget_amount_gaa'].fillna(0)
merged['budget_amount_nep'] = merged['budget_amount_nep'].fillna(0)

# %% [markdown]
# ## Measuring Budget Changes
#
# We calculate:
# - Absolute change (difference in amount)
# - Percentage change (relative adjustment)
#
# Small changes are common and expected.

# %%
# Calculate drift
merged['abs_change'] = merged['budget_amount_gaa'] - merged['budget_amount_nep']
merged['pct_change'] = merged['abs_change'] / merged['budget_amount_nep'].replace(0, 1)

# %% [markdown]
# ## Interpreting Budget Adjustments
#
# - NEP > GAA: Budget reduction
# - NEP < GAA: Budget increase
# - Minimal difference: Approved as proposed

# %%
def classify_adjustment(row):
    if row['pct_change'] > 0.05:
        return "Budget Increase"
    elif row['pct_change'] < -0.05:
        return "Budget Reduction"
    else:
        return "No Significant Change"

merged['adjustment_type'] = merged.apply(classify_adjustment, axis=1)

# %% [markdown]
# ## Anomaly Detection Strategy (Summary)
#
# This project uses multiple anomaly signals to reduce false positives.
# A budget item is flagged only when it meets more than one condition:
#
# - Meaningful budget change
# - Unusual compared to peers
# - Inconsistent with historical behavior
#
# Final decisions are based on a combined anomaly score.

# %% [markdown]
# ### Threshold Selection
#
# Thresholds were chosen to balance sensitivity and false positives.
# They are conservative by design and intended for review support, not enforcement.

# %%
merged['anomaly_threshold'] = (
    (merged['pct_change'].abs() > 0.3) |
    (merged['abs_change'].abs() > 50_000_000)
)

# %% [markdown]
# ### Z-Score (Statistical Outliers)
# Logic:
#
# Compare each item to its peers (same year, same classification).

# %%
merged['z_score'] = merged.groupby(
    ['fiscal_year', 'uacs_object_code']
)['pct_change'].transform(
    lambda x: (x - x.mean()) / x.std(ddof=0)
)

merged['anomaly_zscore'] = merged['z_score'].abs() > 2

# %% [markdown]
# ### Regional Comparison
#
# Regions with no or minimal budget changes are treated as normal outcomes
# of the approval process and are not flagged as anomalies.

# %%
merged['region_mean'] = merged.groupby(
    ['fiscal_year', 'uacs_object_code']
)['pct_change'].transform('mean')

merged['region_std'] = merged.groupby(
    ['fiscal_year', 'uacs_object_code']
)['pct_change'].transform('std')

MIN_CHANGE = 0.05

merged['region_anomaly'] = (
    (merged['pct_change'].abs() > MIN_CHANGE) &
    ((merged['pct_change'] - merged['region_mean']).abs() >
     2 * merged['region_std'])
)

# %% [markdown]
# ### Historical Consistency Check
#
# Logic:
#
# Compare current drift against historical average drift.

# %%
merged['historical_mean'] = merged.groupby(
    ['full_agency_code', 'region_code', 'uacs_object_code']
)['pct_change'].transform('mean')

merged['historical_std'] = merged.groupby(
    ['full_agency_code', 'region_code', 'uacs_object_code']
)['pct_change'].transform('std')

merged['historical_anomaly'] = (
    (merged['pct_change'] - merged['historical_mean']).abs() >
    2 * merged['historical_std']
)

# %% [markdown]
# ## Final Anomaly Scoring

# %%
merged['anomaly_score'] = (
    merged['anomaly_threshold'].astype(int) +
    merged['anomaly_zscore'].astype(int) +
    merged['historical_anomaly'].astype(int) +
    merged['region_anomaly'].astype(int)
)

merged['is_anomaly'] = merged['anomaly_score'] >= 2

# %% [markdown]
# Interpretation
#
# Score 0–1: Normal
#
# Score 2–3: Needs review
#
# Score 4: High-risk anomaly

# %% [markdown]
# ## Natural Language Explanation

# %%
def explain(row):
    reasons = []
    if row['anomaly_threshold']:
        reasons.append("large budget change")
    if row['anomaly_zscore']:
        reasons.append("statistically unusual compared to peers")
    if row['historical_anomaly']:
        reasons.append("inconsistent with historical trends")
    if row['region_anomaly']:
        reasons.append("differs from other regions")
    return '' if not reasons else "Flagged due to: " + ", ".join(reasons)

merged['explanation'] = merged.apply(explain, axis=1)

# %%
# Save the results
merged.to_parquet('detected_anomaly.parquet')

# %% [markdown]
# ## Reviewing Sample Results
#
# The following samples show:
# - Random non-anomalous records
# - Random detected anomalies
#
# This helps validate that the detection logic behaves as expected.

# %%
# Sample some non-anomalies
merged[~merged['is_anomaly']].sample(5, random_state=42)
# Out:
#         fiscal_year department_code  \
# 217230         2024              11
# 38875          2020              20
# 77504          2021              15
# 99769          2021              38
# 39259          2020              20
#
#                                           department_name full_agency_code  \
# 217230                        Department of Finance (DOF)            11003
# 38875   Department of Social Welfare and Development (...            20001
# 77504                         Department of Justice (DOJ)            15002
# 99769                 Department of Transportation (DOTr)            38001
# 39259   Department of Social Welfare and Development (...            20001
#
#                        agency_name region_code            region_description  \
# 217230  Bureau of Internal Revenue          02    Region II - Cagayan Valley
# 38875      Office of the Secretary          07  Region VII - Central Visayas
# 77504        Bureau of Corrections          11             Region XI - Davao
# 99769      Office of the Secretary          02    Region II - Cagayan Valley
# 39259      Office of the Secretary          11             Region XI - Davao
#
#        uacs_object_code       uacs_sub_object_name  budget_amount_nep  ...  \
# 217230       5010214001  Year-End Bonus - Civilian            15507.0  ...
# 38875        5010499015   Loyalty Award - Civilian               50.0  ...
# 77504        5021305001                  Machinery              544.0  ...
# 99769        5010304001            ECIP - Civilian              170.0  ...
# 39259        5021305002           Office Equipment              250.0  ...
#
#         anomaly_zscore  region_mean  region_std region_anomaly  \
# 217230           False     0.000114    0.002248          False
# 38875            False     0.531667   11.234938          False
# 77504            False    -0.004701    0.051380          False
# 99769            False     0.000876    0.025305          False
# 39259            False    -0.002606    0.065819          False
#
#         historical_mean  historical_std  historical_anomaly  anomaly_score  \
# 217230              0.0             0.0               False              0
# 38875               0.0             0.0               False              0
# 77504               0.0             0.0               False              0
# 99769               0.0             0.0               False              0
# 39259               0.0             0.0               False              0
#
#         is_anomaly  explanation
# 217230       False
# 38875        False
# 77504        False
# 99769        False
# 39259        False
#
# [5 rows x 26 columns]

# %%
# Sample some detected anomalies
merged[merged['is_anomaly']].sample(5, random_state=42)
# Out:
#         fiscal_year department_code  \
# 27414          2020              14
# 54241          2020              38
# 171219         2023              13
# 41749          2020              21
# 46722          2020              24
#
#                                           department_name full_agency_code  \
# 27414   Department of the Interior and Local Governmen...            14006
# 54241                 Department of Transportation (DOTr)            38001
# 171219                         Department of Health (DOH)            13001
# 41749                         Department of Tourism (DOT)            21001
# 46722   Department of Economy, Planning, and Developme...            24008
#
#                             agency_name region_code  \
# 27414        Philippine National Police          13
# 54241           Office of the Secretary          16
# 171219          Office of the Secretary          09
# 41749           Office of the Secretary          16
# 46722   Philippine Statistics Authority          13
#
#                      region_description uacs_object_code  \
# 27414     National Capital Region (NCR)       5021503000
# 54241              Region XIII - CARAGA       5029901000
# 171219  Region IX - Zamboanga Peninsula       5020301002
# 41749              Region XIII - CARAGA       5029904000
# 46722     National Capital Region (NCR)       5020301002
#
#                         uacs_sub_object_name  budget_amount_nep  ...  \
# 27414                     Insurance Expenses            68692.0  ...
# 54241                   Advertising Expenses              160.0  ...
# 171219              Office Supplies Expenses            28669.0  ...
# 41749   Transportation and Delivery Expenses              100.0  ...
# 46722               Office Supplies Expenses           149431.0  ...
#
#         anomaly_zscore  region_mean  region_std region_anomaly  \
# 27414             True    -0.003986    0.071424           True
# 54241            False     2.200109   19.612446          False
# 171219           False     0.323357    6.733173          False
# 41749            False     0.246933    3.472248          False
# 46722             True     0.074238    0.430680           True
#
#         historical_mean  historical_std  historical_anomaly  anomaly_score  \
# 27414          0.069482        0.170195                True              4
# 54241         -0.052083        0.127578                True              2
# 171219         0.081389        0.199361                True              2
# 41749          0.131667        0.322516                True              2
# 46722          0.178455        0.437123                True              4
#
#         is_anomaly                                        explanation
# 27414         True  Flagged due to: large budget change, statistic...
# 54241         True  Flagged due to: large budget change, inconsist...
# 171219        True  Flagged due to: large budget change, inconsist...
# 41749         True  Flagged due to: large budget change, inconsist...
# 46722         True  Flagged due to: large budget change, statistic...
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Limitations
#
# - This analysis does not determine intent or correctness
# - Results should be reviewed alongside official documents
# - Some budget changes may be policy-driven or emergency-related

# %% [markdown]
# ## Summary
#
# This notebook demonstrates a transparent and explainable approach
# to identifying unusual budget adjustments between NEP and GAA.
#
# Future improvements include:
# - Multi-year trend analysis
# - Interactive dashboards
# - Integration with Snowflake

# %%
merged[['department_name', 'budget_amount_nep', 'budget_amount_gaa']].groupby('department_name').sum().reset_index().sort_values(by='budget_amount_nep', ascending=False).head(5)
# Out:
#                                       department_name  budget_amount_nep  \
# 24     Department of Public Works and Highways (DPWH)       4.331142e+09
# 12                    Department of Education (DepEd)       4.243126e+09
# 30  Department of the Interior and Local Governmen...       1.557480e+09
# 23               Department of National Defense (DND)       1.383707e+09
# 26  Department of Social Welfare and Development (...       1.371722e+09
#
#     budget_amount_gaa
# 24       5.044799e+09
# 12       4.048367e+09
# 30       1.540868e+09
# 23       1.342079e+09
# 26       1.210721e+09

# %%
import matplotlib.pyplot as plt

sample = merged[['department_name', 'budget_amount_nep', 'budget_amount_gaa']].groupby('department_name').sum().reset_index().sort_values(by='budget_amount_nep', ascending=False).head(12)

plt.figure()
plt.bar(sample['department_name'], sample['budget_amount_nep'], label='NEP')
plt.bar(sample['department_name'], sample['budget_amount_gaa'], bottom=sample['budget_amount_nep'], label='GAA')
plt.title('NEP vs GAA Budget Comparison')
plt.ylabel('Budget Amount')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.tight_layout()
plt.show()

# %%
sample
# Out:
#                                 department_name  budget_amount_nep  \
# 9                Department of Agriculture (DA)        622290202.0
# 10    Department of Budget and Management (DBM)         14611023.0
# 1   Autonomous Region in Muslim Mindanao (ARMM)                0.0
# 37       State Universities and Colleges (SUCs)        594100620.0
# 6              Commission on Human Rights (CHR)          6124744.0
#
#     budget_amount_gaa
# 9         547659593.0
# 10         13952386.0
# 1                 0.0
# 37        647452064.0
# 6           6191895.0

# %%
import numpy as np

sample = merged[['department_name', 'budget_amount_nep', 'budget_amount_gaa']].groupby('department_name').sum().reset_index().sort_values(by='budget_amount_nep', ascending=False).head(12)

x = np.arange(len(sample))
width = 0.35

plt.figure()
plt.bar(x - width/2, sample['budget_amount_nep'], width, label='NEP')
plt.bar(x + width/2, sample['budget_amount_gaa'], width, label='GAA')

plt.xticks(x, sample['department_name'], rotation=45, ha='right')
plt.ylabel('Budget Amount')
plt.title('NEP (Proposed) vs GAA (Approved)')
plt.legend()
plt.tight_layout()
plt.show()
