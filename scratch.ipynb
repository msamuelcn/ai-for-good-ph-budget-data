# %% [markdown]
# # NEP → GAA Budget Anomaly Detection
#
# This notebook analyzes how proposed government budgets (NEP) change after approval (GAA).
# It identifies unusual budget adjustments to support transparency and public understanding.
#
# NEP = Proposed Budget
# GAA = Approved Budget

# %% [markdown]
# ## Background
#
# Government budgets go through a review process before final approval.
# While proposed (NEP) and approved (GAA) budgets are public, understanding how and where changes happen is difficult.
#
# This notebook focuses on:
# - Identifying large or unusual changes
# - Comparing regions fairly
# - Avoiding false alarms
# - Explaining results in simple language

# %% [markdown]
# ## Dataset Overview
#
# The dataset contains budget records with:
# - Budget type (NEP or GAA)
# - Fiscal year
# - Budget amount
# - Agency and region
# - Budget classification and object codes
#
# Only records from a selected agency are analyzed.

# %% [markdown]
# ## Key Definitions
#
# - NEP (National Expenditure Program): Proposed government budget
# - GAA (General Appropriations Act): Final approved budget
# - Budget Drift: Difference between NEP and GAA
# - Anomaly: A budget adjustment that is unusually large or inconsistent with peers or history
#
# Anomalies indicate items that may require review, not wrongdoing.

# %% [markdown]
# ## Data Preparation
#
# We separate NEP and GAA records and aggregate them to a comparable level
# to ensure fair comparison.

# %%
import pandas as pd

df = pd.DataFrame()

fiscl_years = [2020, 2021, 2022, 2023, 2024, 2025, 2026]

for year in fiscl_years:
    df_year = pd.read_parquet(f'cleaned_budget_{year}.parquet', engine='pyarrow')
    df = pd.concat([df, df_year], ignore_index=True)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#              budget_id budget_type  fiscal_year  budget_amount  \
# 0  GAA-2020-0000000001         GAA         2020            0.0
# 1  GAA-2020-0000000002         GAA         2020       543636.0
# 2  GAA-2020-0000000003         GAA         2020        60383.0
# 3  GAA-2020-0000000004         GAA         2020        16824.0
# 4  GAA-2020-0000000005         GAA         2020        11772.0
#
#                    budget_description funding_code  \
# 0  General Administration and Support          nan
# 1  General management and supervision     01101101
# 2  General management and supervision     01101101
# 3  General management and supervision     01101101
# 4  General management and supervision     01101101
#
#                                       funding_source department_code  \
# 0                                               None            None
# 1  Regular Agency Fund - General Fund - New Gener...              01
# 2  Regular Agency Fund - General Fund - New Gener...              01
# 3  Regular Agency Fund - General Fund - New Gener...              01
# 4  Regular Agency Fund - General Fund - New Gener...              01
#
#                           department_name abbreviation agency_code  \
# 0                                    None         None        None
# 1  Congress of the Philippines (CONGRESS)     CONGRESS         001
# 2  Congress of the Philippines (CONGRESS)     CONGRESS         001
# 3  Congress of the Philippines (CONGRESS)     CONGRESS         001
# 4  Congress of the Philippines (CONGRESS)     CONGRESS         001
#
#   full_agency_code agency_name      org_code org_name region_code  \
# 0             None        None           nan     None         nan
# 1            01001      Senate  010010000000   Senate          13
# 2            01001      Senate  010010000000   Senate          13
# 3            01001      Senate  010010000000   Senate          13
# 4            01001      Senate  010010000000   Senate          13
#
#               region_description    prexc_fpap_id uacs_object_code  \
# 0                           None  100000000000000              nan
# 1  National Capital Region (NCR)  100000100001000       5010101001
# 2  National Capital Region (NCR)  100000100001000       5010102000
# 3  National Capital Region (NCR)  100000100001000       5010201001
# 4  National Capital Region (NCR)  100000100001000       5010202000
#
#   uacs_classification      uacs_sub_class          uacs_group  \
# 0                None                None                None
# 1            Expenses  Personnel Services  Salaries and Wages
# 2            Expenses  Personnel Services  Salaries and Wages
# 3            Expenses  Personnel Services  Other Compensation
# 4            Expenses  Personnel Services  Other Compensation
#
#                             uacs_object_name  \
# 0                                       None
# 1               Salaries and Wages - Regular
# 2    Salaries and Wages - Casual/Contractual
# 3  Personal Economic Relief Allowance (PERA)
# 4              Representation Allowance (RA)
#
#                       uacs_sub_object_name
# 0                                     None
# 1                  Basic Salary - Civilian
# 2  Salaries and Wages - Casual/Contractual
# 3                          PERA - Civilian
# 4            Representation Allowance (RA)

# %%
nep = df[df['budget_type'] == 'NEP']
gaa = df[df['budget_type'] == 'GAA']

# Aggregate to comparable level
group_cols = [
    'fiscal_year',
    'department_code',
    'department_name',
    'full_agency_code',
    'agency_name',
    'region_code',
    'region_description',
    'budget_description',
    'prexc_fpap_id'
]

nep_agg = nep.groupby(group_cols)['budget_amount'].sum().reset_index()
gaa_agg = gaa.groupby(group_cols)['budget_amount'].sum().reset_index()

merged = nep_agg.merge(
    gaa_agg,
    on=group_cols,
    suffixes=('_nep', '_gaa'),
    how='outer'
)

# %%
merged[merged['budget_description']=='Construction of Multi-Purpose Building, Barangay Kamuning, Puerto Princesa City, Palawan']#.sample(6)#[merged['prexc_fpap_id']=='300104215736000']#.sample(6)

# %%
merged['unapproved_budget'] = merged['budget_amount_gaa'].isna()
merged['inserted_budget'] = merged['budget_amount_nep'].isna()
merged['budget_amount_gaa'] = merged['budget_amount_gaa'].fillna(0)
merged['budget_amount_nep'] = merged['budget_amount_nep'].fillna(0)

# %% [markdown]
# ## Measuring Budget Changes
#
# We calculate:
# - Absolute change (difference in amount)
# - Percentage change (relative adjustment)
#
# Small changes are common and expected.

# %%
# Calculate drift
merged['abs_change'] = merged['budget_amount_gaa'] - merged['budget_amount_nep']
merged['pct_change'] = merged['abs_change'] / merged['budget_amount_nep'].replace(0, 1)

# %% [markdown]
# ## Interpreting Budget Adjustments
#
# - NEP > GAA: Budget reduction
# - NEP < GAA: Budget increase
# - Minimal difference: Approved as proposed

# %%
merged
# Out:
#         fiscal_year department_code                         department_name  \
# 0              2020              01  Congress of the Philippines (CONGRESS)
# 1              2020              01  Congress of the Philippines (CONGRESS)
# 2              2020              01  Congress of the Philippines (CONGRESS)
# 3              2020              01  Congress of the Philippines (CONGRESS)
# 4              2020              01  Congress of the Philippines (CONGRESS)
# ...             ...             ...                                     ...
# 257284         2026              40     Department of Migrant Workers (DMW)
# 257285         2026              40     Department of Migrant Workers (DMW)
# 257286         2026              40     Department of Migrant Workers (DMW)
# 257287         2026              40     Department of Migrant Workers (DMW)
# 257288         2026              40     Department of Migrant Workers (DMW)
#
#        full_agency_code                              agency_name region_code  \
# 0                 01001                                   Senate          13
# 1                 01001                                   Senate          13
# 2                 01001                                   Senate          13
# 3                 01001                                   Senate          13
# 4                 01002                Senate Electoral Tribunal          13
# ...                 ...                                      ...         ...
# 257284            40002  Overseas Workers Welfare Administration          13
# 257285            40002  Overseas Workers Welfare Administration          13
# 257286            40002  Overseas Workers Welfare Administration          13
# 257287            40002  Overseas Workers Welfare Administration          13
# 257288            40002  Overseas Workers Welfare Administration          13
#
#                    region_description  \
# 0       National Capital Region (NCR)
# 1       National Capital Region (NCR)
# 2       National Capital Region (NCR)
# 3       National Capital Region (NCR)
# 4       National Capital Region (NCR)
# ...                               ...
# 257284  National Capital Region (NCR)
# 257285  National Capital Region (NCR)
# 257286  National Capital Region (NCR)
# 257287  National Capital Region (NCR)
# 257288  National Capital Region (NCR)
#
#                                        budget_description    prexc_fpap_id  \
# 0                    Administration of Personnel Benefits  100000100002000
# 1                      General management and supervision  100000100001000
# 2        Legislation of Laws and Other Related Activities  310100100001000
# 3                                       Senate Relocation  100000200001000
# 4       Adjudication of Electoral Contests involving M...  310100100001000
# ...                                                   ...              ...
# 257284               Administration of Personnel Benefits  100000100002000
# 257285                 General Management and Supervision  100000100001000
# 257286                               Membership Promotion  310100100003000
# 257287                     Training and Scholarship Grant  310100100001000
# 257288                                   Welfare Services  310100100002000
#
#         budget_amount_nep  budget_amount_gaa  unapproved_budget  \
# 0                213401.0           213401.0              False
# 1               2216813.0          2559213.0              False
# 2               2353949.0          2483549.0              False
# 3               2877000.0          4387000.0              False
# 4                110724.0           110724.0              False
# ...                   ...                ...                ...
# 257284            13935.0                0.0               True
# 257285          1024214.0                0.0               True
# 257286            72631.0                0.0               True
# 257287            36581.0                0.0               True
# 257288          2337997.0                0.0               True
#
#         inserted_budget  abs_change  pct_change
# 0                 False         0.0    0.000000
# 1                 False    342400.0    0.154456
# 2                 False    129600.0    0.055056
# 3                 False   1510000.0    0.524852
# 4                 False         0.0    0.000000
# ...                 ...         ...         ...
# 257284            False    -13935.0   -1.000000
# 257285            False  -1024214.0   -1.000000
# 257286            False    -72631.0   -1.000000
# 257287            False    -36581.0   -1.000000
# 257288            False  -2337997.0   -1.000000
#
# [257289 rows x 15 columns]

# %%
def classify_adjustment(row):
    if row['unapproved_budget']:
        return "Unapproved Budget"
    elif row['inserted_budget']:
        return "Inserted Budget"
    elif row['pct_change'] > 0.05:
        return "Budget Increase"
    elif row['pct_change'] < -0.05:
        return "Budget Reduction"
    else:
        return "No Significant Change"

merged['adjustment_type'] = merged.apply(classify_adjustment, axis=1)

# %% [markdown]
# ## Anomaly Detection Strategy (Summary)
#
# This project uses multiple anomaly signals to reduce false positives.
# A budget item is flagged only when it meets more than one condition:
#
# - Meaningful budget change
# - Unusual compared to peers
# - Inconsistent with historical behavior
#
# Final decisions are based on a combined anomaly score.

# %% [markdown]
# ### Threshold Selection
#
# Thresholds were chosen to balance sensitivity and false positives.
# They are conservative by design and intended for review support, not enforcement.

# %%
merged['anomaly_threshold'] = (
    (merged['pct_change'].abs() > 0.3) |
    (merged['abs_change'].abs() > 50_000_000)
)

# %% [markdown]
# ### Z-Score (Statistical Outliers)
# Logic:
#
# Compare each item to its peers (same year, same classification).

# %%
merged['z_score'] = merged.groupby(
    ['fiscal_year', 'budget_description']
)['pct_change'].transform(
    lambda x: (x - x.mean()) / x.std(ddof=0)
)

merged['anomaly_zscore'] = merged['z_score'].abs() > 2

# %% [markdown]
# ### Regional Comparison
#
# Regions with no or minimal budget changes are treated as normal outcomes
# of the approval process and are not flagged as anomalies.

# %%
merged['region_mean'] = merged.groupby(
    ['fiscal_year', 'budget_description']
)['pct_change'].transform('mean')

merged['region_std'] = merged.groupby(
    ['fiscal_year', 'budget_description']
)['pct_change'].transform('std')

MIN_CHANGE = 0.05

merged['region_anomaly'] = (
    (merged['pct_change'].abs() > MIN_CHANGE) &
    ((merged['pct_change'] - merged['region_mean']).abs() >
     2 * merged['region_std'])
)

# %% [markdown]
# ### Historical Consistency Check
#
# Logic:
#
# Compare current drift against historical average drift.

# %%
merged['historical_mean'] = merged.groupby(
    ['full_agency_code', 'region_code', 'budget_description']
)['pct_change'].transform('mean')

merged['historical_std'] = merged.groupby(
    ['full_agency_code', 'region_code', 'budget_description']
)['pct_change'].transform('std')

merged['historical_anomaly'] = (
    (merged['pct_change'] - merged['historical_mean']).abs() >
    2 * merged['historical_std']
)

# %% [markdown]
# ## Final Anomaly Scoring

# %%
merged['anomaly_score'] = (
    merged['anomaly_threshold'].astype(int) +
    merged['anomaly_zscore'].astype(int) +
    merged['historical_anomaly'].astype(int) +
    merged['region_anomaly'].astype(int)
)

merged['is_anomaly'] = merged['anomaly_score'] >= 2

# %% [markdown]
# Interpretation
#
# Score 0–1: Normal
#
# Score 2–3: Needs review
#
# Score 4: High-risk anomaly

# %% [markdown]
# ## Natural Language Explanation

# %%
def explain(row):
    reasons = []
    if row['anomaly_threshold']:
        reasons.append("large budget change")
    if row['anomaly_zscore']:
        reasons.append("statistically unusual compared to peers")
    if row['historical_anomaly']:
        reasons.append("inconsistent with historical trends")
    if row['region_anomaly']:
        reasons.append("differs from other regions")
    return '' if not reasons else "Flagged due to: " + ", ".join(reasons)

merged['explanation'] = merged.apply(explain, axis=1)

# %%
# Save the results
merged.to_parquet('detected_anomaly_project.parquet')

# %% [markdown]
# ## Reviewing Sample Results
#
# The following samples show:
# - Random non-anomalous records
# - Random detected anomalies
#
# This helps validate that the detection logic behaves as expected.

# %%
# Sample some non-anomalies
merged[~merged['is_anomaly']].sample(5)
# Out:
#         fiscal_year department_code  \
# 71663          2021              18
# 32834          2020              18
# 211916         2025              18
# 232178         2025              18
# 243013         2026              05
#
#                                        department_name full_agency_code  \
# 71663   Department of Public Works and Highways (DPWH)            18001
# 32834   Department of Public Works and Highways (DPWH)            18001
# 211916  Department of Public Works and Highways (DPWH)            18001
# 232178  Department of Public Works and Highways (DPWH)            18001
# 243013                  Department of Agriculture (DA)            05001
#
#                     agency_name region_code               region_description  \
# 71663   Office of the Secretary          09  Region IX - Zamboanga Peninsula
# 32834   Office of the Secretary          11                Region XI - Davao
# 211916  Office of the Secretary          02       Region II - Cagayan Valley
# 232178  Office of the Secretary          13    National Capital Region (NCR)
# 243013  Office of the Secretary          06      Region VI - Western Visayas
#
#                                        budget_description    prexc_fpap_id  \
# 71663   NRJ leading to Basay Falls, Barangay Culasian,...  300203101883000
# 32834   Construction of footbridges, Brgy. Ilang, Dava...  300119200402000
# 211916  Construction of Bridge and Installation of RC ...  300221107778000
# 232178  Pangasinan-Zambales Road to Judge Jose De Vene...  310204102892000
# 243013  Modernization and Strengthening of Production ...  200000100015000
#
#         budget_amount_nep  budget_amount_gaa  unapproved_budget  \
# 71663                 0.0             7500.0              False
# 32834                 0.0             3000.0              False
# 211916                0.0            10000.0              False
# 232178                0.0            70000.0              False
# 243013            61981.0                0.0               True
#
#         inserted_budget  abs_change  pct_change    adjustment_type  \
# 71663              True      7500.0      7500.0    Inserted Budget
# 32834              True      3000.0      3000.0    Inserted Budget
# 211916             True     10000.0     10000.0    Inserted Budget
# 232178             True     70000.0     70000.0    Inserted Budget
# 243013            False    -61981.0        -1.0  Unapproved Budget
#
#         anomaly_threshold  z_score  anomaly_zscore  region_mean  region_std  \
# 71663                True      NaN           False       7500.0         NaN
# 32834                True      NaN           False       3000.0         NaN
# 211916               True      NaN           False      10000.0         NaN
# 232178               True      NaN           False      70000.0         NaN
# 243013               True      NaN           False         -1.0         0.0
#
#         region_anomaly  historical_mean  historical_std  historical_anomaly  \
# 71663            False     10023.166667     1625.490746               False
# 32834            False      3000.000000             NaN               False
# 211916           False     10000.000000             NaN               False
# 232178           False     70000.000000             NaN               False
# 243013           False        -1.000000             NaN               False
#
#         anomaly_score  is_anomaly                          explanation
# 71663               1       False  Flagged due to: large budget change
# 32834               1       False  Flagged due to: large budget change
# 211916              1       False  Flagged due to: large budget change
# 232178              1       False  Flagged due to: large budget change
# 243013              1       False  Flagged due to: large budget change

# %%
# Sample some detected anomalies
merged[(merged['is_anomaly']) & (~merged['unapproved_budget'])  & (merged['abs_change'] >1000000)].sample(7)
# Out:
#         fiscal_year department_code  \
# 131833         2023              17
# 164217         2024              05
# 155913         2023              20
# 48474          2020              35
# 125256         2023              05
# 196950         2024              20
# 210016         2025              16
#
#                                           department_name full_agency_code  \
# 131833               Department of National Defense (DND)            17006
# 164217                     Department of Agriculture (DA)            05003
# 155913  Department of Social Welfare and Development (...            20001
# 48474   Budgetary Support to Government Corporations (...            35005
# 125256                     Department of Agriculture (DA)            05002
# 196950  Department of Social Welfare and Development (...            20001
# 210016          Department of Labor and Employment (DOLE)            16009
#
#                                               agency_name region_code  \
# 131833                   Veterans Memorial Medical Center          13
# 164217          Bureau of Fisheries and Aquatic Resources          13
# 155913                            Office of the Secretary          07
# 48474                  National Irrigation Administration          13
# 125256                 Agricultural Credit Policy Council          13
# 196950                            Office of the Secretary          13
# 210016  Technical Education and Skills Development Aut...          13
#
#                    region_description  \
# 131833  National Capital Region (NCR)
# 164217  National Capital Region (NCR)
# 155913   Region VII - Central Visayas
# 48474   National Capital Region (NCR)
# 125256  National Capital Region (NCR)
# 196950  National Capital Region (NCR)
# 210016  National Capital Region (NCR)
#
#                                        budget_description    prexc_fpap_id  \
# 131833                                    In-Patient care  310100100001000
# 164217               Monitoring, control and surveillance  310200100001000
# 155913  Pantawid Pamilyang Pilipino Program (Implement...  310100100001000
# 48474          Small Irrigation Project (SIP), Nationwide  310204200001000
# 125256  Agro-Industry Modernization Credit and Financi...  310100100001000
# 196950                     Sustainable Livelihood Program  310100100002000
# 210016  Promotion, Development, Implementation, Monito...  310300100002000
#
#         budget_amount_nep  budget_amount_gaa  unapproved_budget  \
# 131833                0.0          1459181.0              False
# 164217           477771.0          2377771.0              False
# 155913                0.0          7494027.0              False
# 48474                 0.0          5023478.0              False
# 125256                0.0          2773403.0              False
# 196950          4081032.0          6090151.0              False
# 210016          2088722.0          3726222.0              False
#
#         inserted_budget  abs_change    pct_change  adjustment_type  \
# 131833             True   1459181.0  1.459181e+06  Inserted Budget
# 164217            False   1900000.0  3.976801e+00  Budget Increase
# 155913             True   7494027.0  7.494027e+06  Inserted Budget
# 48474              True   5023478.0  5.023478e+06  Inserted Budget
# 125256             True   2773403.0  2.773403e+06  Inserted Budget
# 196950            False   2009119.0  4.923066e-01  Budget Increase
# 210016            False   1637500.0  7.839722e-01  Budget Increase
#
#         anomaly_threshold   z_score  anomaly_zscore   region_mean  \
# 131833               True       NaN           False  1.459181e+06
# 164217               True  3.872983            True  2.485500e-01
# 155913               True  0.511234           False  6.413155e+06
# 48474                True  3.872983            True  3.139664e+05
# 125256               True       NaN           False  2.773403e+06
# 196950               True  3.872983            True  3.076916e-02
# 210016               True  3.872983            True  4.899826e-02
#
#           region_std  region_anomaly  historical_mean  historical_std  \
# 131833           NaN           False     2.084543e+05    5.515186e+05
# 164217  9.942002e-01            True     3.310666e-01    1.651253e+00
# 155913  2.183580e+06           False     1.070575e+06    2.832476e+06
# 48474   1.255870e+06            True     1.004695e+06    2.246568e+06
# 125256           NaN           False     3.962001e+05    1.048248e+06
# 196950  1.230767e-01            True     2.491299e-01    6.753516e-01
# 210016  1.959931e-01            True     6.454708e+05    1.290939e+06
#
#         historical_anomaly  anomaly_score  is_anomaly  \
# 131833                True              2        True
# 164217                True              4        True
# 155913                True              2        True
# 48474                False              3        True
# 125256                True              2        True
# 196950               False              3        True
# 210016               False              3        True
#
#                                               explanation
# 131833  Flagged due to: large budget change, inconsist...
# 164217  Flagged due to: large budget change, statistic...
# 155913  Flagged due to: large budget change, inconsist...
# 48474   Flagged due to: large budget change, statistic...
# 125256  Flagged due to: large budget change, inconsist...
# 196950  Flagged due to: large budget change, statistic...
# 210016  Flagged due to: large budget change, statistic...

# %%
pd.set_option('display.max_rows', None)
df[ (df['department_name'] == 'Department of Public Works and Highways (DPWH)') & (df['budget_type'] == 'GAA') ].groupby(['fiscal_year','budget_type','department_name','uacs_object_code','uacs_sub_object_name'])['budget_amount'].sum().reset_index().sort_values(by=['budget_type','budget_amount','fiscal_year','budget_type'],ascending=False,).head(100)
# Out:
#      fiscal_year budget_type                                 department_name  \
# 444         2025         GAA  Department of Public Works and Highways (DPWH)
# 370         2024         GAA  Department of Public Works and Highways (DPWH)
# 223         2022         GAA  Department of Public Works and Highways (DPWH)
# 295         2023         GAA  Department of Public Works and Highways (DPWH)
# 422         2025         GAA  Department of Public Works and Highways (DPWH)
# 202         2022         GAA  Department of Public Works and Highways (DPWH)
# 313         2024         GAA  Department of Public Works and Highways (DPWH)
# 239         2023         GAA  Department of Public Works and Highways (DPWH)
# 228         2022         GAA  Department of Public Works and Highways (DPWH)
# 50          2020         GAA  Department of Public Works and Highways (DPWH)
# 59          2020         GAA  Department of Public Works and Highways (DPWH)
# 168         2022         GAA  Department of Public Works and Highways (DPWH)
# 96          2021         GAA  Department of Public Works and Highways (DPWH)
# 12          2020         GAA  Department of Public Works and Highways (DPWH)
# 384         2025         GAA  Department of Public Works and Highways (DPWH)
# 386         2025         GAA  Department of Public Works and Highways (DPWH)
# 309         2024         GAA  Department of Public Works and Highways (DPWH)
# 311         2024         GAA  Department of Public Works and Highways (DPWH)
# 234         2023         GAA  Department of Public Works and Highways (DPWH)
# 236         2023         GAA  Department of Public Works and Highways (DPWH)
# 131         2021         GAA  Department of Public Works and Highways (DPWH)
# 302         2023         GAA  Department of Public Works and Highways (DPWH)
# 149         2021         GAA  Department of Public Works and Highways (DPWH)
# 75          2020         GAA  Department of Public Works and Highways (DPWH)
# 164         2022         GAA  Department of Public Works and Highways (DPWH)
# 166         2022         GAA  Department of Public Works and Highways (DPWH)
# 276         2023         GAA  Department of Public Works and Highways (DPWH)
# 349         2024         GAA  Department of Public Works and Highways (DPWH)
# 92          2021         GAA  Department of Public Works and Highways (DPWH)
# 94          2021         GAA  Department of Public Works and Highways (DPWH)
# 7           2020         GAA  Department of Public Works and Highways (DPWH)
# 11          2020         GAA  Department of Public Works and Highways (DPWH)
# 100         2021         GAA  Department of Public Works and Highways (DPWH)
# 377         2024         GAA  Department of Public Works and Highways (DPWH)
# 130         2021         GAA  Department of Public Works and Highways (DPWH)
# 380         2025         GAA  Department of Public Works and Highways (DPWH)
# 83          2020         GAA  Department of Public Works and Highways (DPWH)
# 305         2024         GAA  Department of Public Works and Highways (DPWH)
# 230         2023         GAA  Department of Public Works and Highways (DPWH)
# 203         2022         GAA  Department of Public Works and Highways (DPWH)
# 282         2023         GAA  Department of Public Works and Highways (DPWH)
# 204         2022         GAA  Department of Public Works and Highways (DPWH)
# 392         2025         GAA  Department of Public Works and Highways (DPWH)
# 451         2025         GAA  Department of Public Works and Highways (DPWH)
# 431         2025         GAA  Department of Public Works and Highways (DPWH)
# 356         2024         GAA  Department of Public Works and Highways (DPWH)
#
#     uacs_object_code                      uacs_sub_object_name  budget_amount
# 444       5060403001                             Road Networks    585883409.0
# 370       5060403001                             Road Networks    492815014.0
# 223       5060403001                             Road Networks    470335084.0
# 295       5060403001                             Road Networks    459391292.0
# 150       5060403001                             Road Networks    414564314.0
# 371       5060403002                     Flood Control Systems    349332963.0
# 445       5060403002                     Flood Control Systems    346620462.0
# 76        5060403001                             Road Networks    338246670.0
# 296       5060403002                     Flood Control Systems    280667834.0
# 224       5060403002                     Flood Control Systems    208903148.0
# 151       5060403002                     Flood Control Systems    140612349.0
# 77        5060403002                     Flood Control Systems    116047037.0
# 236       5010216001                 Mid-Year Bonus - Civilian       725580.0
# 131       5021304001                                 Buildings       709187.0
# 302       5060405099             Other Machinery and Equipment       692964.0
# 149       5029999099  Other Maintenance and Operating Expenses       626440.0
# 75        5029999099  Other Maintenance and Operating Expenses       626440.0
# 164       5010214001                 Year-End Bonus - Civilian       607367.0
# 166       5010216001                 Mid-Year Bonus - Civilian       607367.0
# 276       5021304001                                 Buildings       605933.0
# 349       5021304001                                 Buildings       605248.0
# 92        5010214001                 Year-End Bonus - Civilian       590247.0
# 94        5010216001                 Mid-Year Bonus - Civilian       590247.0
# 7         5010214001                 Year-End Bonus - Civilian       547848.0
# 11        5010299036                 Mid-Year Bonus - Civilian       547848.0
# 100       5010403001        Terminal Leave Benefits - Civilian       535433.0
# 377       5060405099             Other Machinery and Equipment       502484.0
# 130       5021303099               Other Infrastructure Assets       488044.0
# 380       5010201001                           PERA - Civilian       482328.0
# 83        5060404099                          Other Structures       480000.0
# 305       5010201001                           PERA - Civilian       479256.0
# 230       5010201001                           PERA - Civilian       476880.0
# 203       5021303099               Other Infrastructure Assets       472955.0
# 282       5021306099            Other Transportation Equipment       471059.0
# 204       5021304001                                 Buildings       461650.0
# 392       5010403001        Terminal Leave Benefits - Civilian       458845.0
# 451       5060405099             Other Machinery and Equipment       455479.0
# 431       5021306099            Other Transportation Equipment       442593.0
# 356       5021306099            Other Transportation Equipment       441353.0

# %%
df

# %% [markdown]
# ## Limitations
#
# - This analysis does not determine intent or correctness
# - Results should be reviewed alongside official documents
# - Some budget changes may be policy-driven or emergency-related

# %% [markdown]
# ## Summary
#
# This notebook demonstrates a transparent and explainable approach
# to identifying unusual budget adjustments between NEP and GAA.
#
# Future improvements include:
# - Multi-year trend analysis
# - Interactive dashboards
# - Integration with Snowflake

# %%
merged[['department_name', 'budget_amount_nep', 'budget_amount_gaa']].groupby('department_name').sum().reset_index().sort_values(by='budget_amount_nep', ascending=False).head(5)

# %%
import matplotlib.pyplot as plt

sample = merged[['department_name', 'budget_amount_nep', 'budget_amount_gaa']].groupby('department_name').sum().reset_index().sort_values(by='budget_amount_nep', ascending=False).head(12)

plt.figure()
plt.bar(sample['department_name'], sample['budget_amount_nep'], label='NEP')
plt.bar(sample['department_name'], sample['budget_amount_gaa'], bottom=sample['budget_amount_nep'], label='GAA')
plt.title('NEP vs GAA Budget Comparison')
plt.ylabel('Budget Amount')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.tight_layout()
plt.show()

# %%
sample

# %%
import numpy as np

sample = merged[['department_name', 'budget_amount_nep', 'budget_amount_gaa']].groupby('department_name').sum().reset_index().sort_values(by='budget_amount_nep', ascending=False).head(12)

x = np.arange(len(sample))
width = 0.35

plt.figure()
plt.bar(x - width/2, sample['budget_amount_nep'], width, label='NEP')
plt.bar(x + width/2, sample['budget_amount_gaa'], width, label='GAA')

plt.xticks(x, sample['department_name'], rotation=45, ha='right')
plt.ylabel('Budget Amount')
plt.title('NEP (Proposed) vs GAA (Approved)')
plt.legend()
plt.tight_layout()
plt.show()
