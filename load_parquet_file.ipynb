# %%
import pandas as pd
from pathlib import Path

# %%
path = Path("preaggregated_budget_details.parquet")
df = pd.read_parquet(path)

# %%
bq load \
  --source_format=PARQUET \
  --location=asia-southeast1 \
  ai_for_good.detected_anomaly \
  "gs://temporary-ai-for-good/detected_anomaly.parquet"
# Out:
# Index(['fiscal_year', 'department_code', 'department_name', 'region_code',
#        'region_description', 'uacs_object_code', 'org_code', 'org_name',
#        'budget_description', 'funding_source', 'full_agency_code',
#        'agency_name', 'GAA', 'NEP', 'budget_amount_nep', 'budget_amount_gaa',
#        'abs_change', 'pct_change', 'is_inserted_budget',
#        'is_unapproved_budget'],
#       dtype='str')
